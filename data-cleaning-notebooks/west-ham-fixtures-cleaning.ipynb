# %% [markdown]
# ## Cleaning Fixture Data
#
# I have scraped West Ham's goals and expected goals from FBRef and will clean them for visualisation in Tableau.

# %%
import pandas as pd
import numpy as np

# loading and cleaning West Ham fixtures data
west_ham_fixtures = pd.read_csv('../data/West-Ham-United-Scores-and-Fixtures.csv')
west_ham_fixtures = west_ham_fixtures.drop(['Unnamed: 0'], axis=1)
west_ham_fixtures = west_ham_fixtures.dropna().reset_index()

west_ham_fixtures.head()
# Out:
#    index  xg_for  xg_against  goals_against  goals_for        round
# 0      0     0.7         3.3            5.0        0.0  Matchweek 1
# 1      1     0.8         1.7            1.0        1.0  Matchweek 2
# 2      2     3.3         2.5            1.0        3.0  Matchweek 3
# 3      4     1.8         1.3            0.0        2.0  Matchweek 4
# 4      5     0.5         1.0            0.0        0.0  Matchweek 5

# %%
west_ham_fixtures['goal_diff'] = west_ham_fixtures['goals_for'] - west_ham_fixtures['goals_against']
west_ham_fixtures['xg_diff'] = west_ham_fixtures['xg_for'] - west_ham_fixtures['xg_against']
west_ham_fixtures.head()
# Out:
#    index  xg_for  xg_against  goals_against  goals_for        round  \
# 0      0     0.7         3.3            5.0        0.0  Matchweek 1
# 1      1     0.8         1.7            1.0        1.0  Matchweek 2
# 2      2     3.3         2.5            1.0        3.0  Matchweek 3
# 3      4     1.8         1.3            0.0        2.0  Matchweek 4
# 4      5     0.5         1.0            0.0        0.0  Matchweek 5
#
#    goal_diff  xg_diff
# 0       -5.0     -2.6
# 1        0.0     -0.9
# 2        2.0      0.8
# 3        2.0      0.5
# 4        0.0     -0.5

# %%
west_ham_fixtures.to_csv("../data/West-Ham-Fixture")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-24-7514be9fea87> in <module>
# ----> 1 west_ham_fixtures.to_csv("../data")
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# IsADirectoryError: [Errno 21] Is a directory: '../data'
